# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from lightgbm import LGBMClassifier
import optuna

# === Helper: Simplify color into dark/light/mixed/other ===
def simplify_color(color):
    color = str(color).lower()
    light = ['white', 'cream', 'tan', 'yellow', 'fawn']
    dark = ['black', 'brown', 'chocolate', 'blue', 'gray', 'grey']
    if any(w in color for w in light) and any(w in color for w in dark):
        return 'mixed'
    elif any(w in color for w in light):
        return 'light'
    elif any(w in color for w in dark):
        return 'dark'
    else:
        return 'other'

# === Helper: Convert age to weeks ===
def age_to_days(age_str):
    if pd.isnull(age_str):
        return np.nan
    num, unit = age_str.split()
    num = int(num)
    unit = unit.lower()
    if 'day' in unit:
        return num
    elif 'week' in unit:
        return num * 7
    elif 'month' in unit:
        return num * 30
    elif 'year' in unit:
        return num * 365
    return np.nan

# === Load and preprocess train.csv ===
train_df = pd.read_csv("train.csv")

target_col = "Outcome Type"
id_col = "Id"

drop_cols = ['Outcome Time', 'Found Location', 'Date of Birth', 'Name', target_col, id_col]
X = train_df.drop(columns=drop_cols, errors='ignore')
y = train_df[target_col]

# Label encode target
le_y = LabelEncoder()
y_encoded = le_y.fit_transform(y)

# Feature engineering
X['Color Category'] = X['Color'].apply(simplify_color)
X.drop(columns=['Color'], inplace=True)

X['Age in Days'] = X['Age upon Intake'].apply(age_to_days)
X.drop(columns=['Age upon Intake'], inplace=True)

# X['Age Group'] = X['Age in Weeks'].apply(age_group)
# X = X.drop(columns=['Age in Weeks'])

# Categorize intake time into hour, weekday, and season (slightly improved accuracy by about .01%: .62 to .63)
X['Intake Time'] = pd.to_datetime(train_df['Intake Time'], errors='coerce')
X['Intake Hour'] = X['Intake Time'].dt.hour
X['Weekday'] = X['Intake Time'].dt.weekday
X['Season'] = X['Intake Time'].dt.month.map({
    12: 'winter', 1: 'winter', 2: 'winter',
    3: 'spring', 4: 'spring', 5: 'spring',
    6: 'summer', 7: 'summer', 8: 'summer',
    9: 'fall', 10: 'fall', 11: 'fall'
})

X.drop(columns=['Intake Time'], inplace=True, errors='ignore')

# Fill missing values
for col in X.columns:
    if X[col].dtype == 'object':
        X[col] = X[col].fillna("Unknown")
    else:
        X[col] = X[col].fillna(X[col].median())

# Convert categoricals to category dtype for LightGBM
categorical_cols = X.select_dtypes(include='object').columns.tolist()
for col in categorical_cols:
    X[col] = X[col].astype('category')

X.head()
# Out:
#        Intake Type Intake Condition Animal Type Sex upon Intake  \
# 0            Stray           Normal         Dog   Spayed Female
# 1            Stray           Normal         Dog     Intact Male
# 2    Public Assist           Normal         Cat   Neutered Male
# 3  Owner Surrender           Normal         Dog   Neutered Male
# 4    Public Assist           Normal         Dog   Neutered Male
#
#                       Breed Color Category  Age in Days  Intake Hour  Weekday  \
# 0  English Springer Spaniel          light       2920.0           12        6
# 1               Basenji Mix          light        330.0           18        3
# 2        Domestic Shorthair          other        730.0            0        3
# 3    Labrador Retriever Mix           dark        730.0           12        5
# 4            Great Dane Mix           dark       2190.0            9        1
#
#    Season
# 0  summer
# 1  spring
# 2  spring
# 3  winter
# 4  spring

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import balanced_accuracy_score

# === Optuna tuning ===
def objective(trial):
    params = {
        'objective': 'multiclass',
        'num_class': len(le_y.classes_),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 15, 63),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 5.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 5.0),
        'random_state': 42,
        'n_estimators': 200,
        'verbosity': -1,
        'is_unbalance': True
    }
    model = LGBMClassifier(**params)

    # Make sure class balance is maintained in each fold: gave highest accuracy of .639
    # skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    # score = cross_val_score(model, X, y_encoded, cv=skf, scoring='accuracy').mean()

    # Use balanced accuracy score instead of accuracy
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = []
    for train_idx, val_idx in skf.split(X, y_encoded):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y_encoded[train_idx], y_encoded[val_idx]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)
        score = balanced_accuracy_score(y_val, y_pred)
        scores.append(score)

    return np.mean(scores)

    # return score

# %%
print("Starting Optuna hyperparameter search...")
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
print(f"\nBest params: {study.best_params}")

# === Train best model on full training data ===
best_params = study.best_params
best_params.update({
    'objective': 'multiclass',
    'num_class': len(le_y.classes_),
    'random_state': 42,
    'n_estimators': 200,
    'is_unbalance': True
})

# best_model = LGBMClassifier(**best_params)
# best_model.fit(X, y_encoded)

# print("\nModel training complete and ready for prediction!")

from sklearn.model_selection import train_test_split

# Split off validation set
X_train_part, X_val_part, y_train_part, y_val_part = train_test_split(
    X, y_encoded, stratify=y_encoded, test_size=0.2, random_state=42)

# Train on 80%
final_model = LGBMClassifier(**best_params)
final_model.fit(X_train_part, y_train_part)

# Evaluate on 20%
y_val_pred = final_model.predict(X_val_part)
val_balanced_acc = balanced_accuracy_score(y_val_part, y_val_pred)

print(f"\nFinal Balanced Accuracy on held-out validation set: {val_balanced_acc:.4f}")
# Out:
# [I 2025-04-15 20:32:50,432] A new study created in memory with name: no-name-45bcf973-1a1b-4bf8-a8a6-f17451723a61
# Starting Optuna hyperparameter search...
# [I 2025-04-15 20:33:07,102] Trial 0 finished with value: 0.6368109590864182 and parameters: {'learning_rate': 0.15351546880594447, 'max_depth': 11, 'num_leaves': 31, 'min_child_samples': 91, 'subsample': 0.9308653671796123, 'colsample_bytree': 0.9846328499239296, 'reg_alpha': 2.8265547986872637, 'reg_lambda': 0.6035500532463162}. Best is trial 0 with value: 0.6368109590864182.
# [I 2025-04-15 20:33:28,056] Trial 1 finished with value: 0.638943083297139 and parameters: {'learning_rate': 0.10888902187401671, 'max_depth': 12, 'num_leaves': 35, 'min_child_samples': 15, 'subsample': 0.5722793460411375, 'colsample_bytree': 0.6396660286828952, 'reg_alpha': 2.6029015273092266, 'reg_lambda': 3.3897260782941148}. Best is trial 1 with value: 0.638943083297139.
# [I 2025-04-15 20:33:46,706] Trial 2 finished with value: 0.6375126689567193 and parameters: {'learning_rate': 0.048968770538089, 'max_depth': 8, 'num_leaves': 40, 'min_child_samples': 98, 'subsample': 0.6433094321091599, 'colsample_bytree': 0.8616957283168978, 'reg_alpha': 1.6870539021601512, 'reg_lambda': 0.41512690116264017}. Best is trial 1 with value: 0.638943083297139.
# [I 2025-04-15 20:34:00,775] Trial 3 finished with value: 0.6366760245302242 and parameters: {'learning_rate': 0.06121896040039912, 'max_depth': 12, 'num_leaves': 23, 'min_child_samples': 44, 'subsample': 0.9361855967292534, 'colsample_bytree': 0.9178417237793539, 'reg_alpha': 1.5454087266292764, 'reg_lambda': 2.7923097991867376}. Best is trial 1 with value: 0.638943083297139.
# [I 2025-04-15 20:34:12,283] Trial 4 finished with value: 0.6356774367845464 and parameters: {'learning_rate': 0.19790143508760197, 'max_depth': 5, 'num_leaves': 34, 'min_child_samples': 24, 'subsample': 0.8341935166128909, 'colsample_bytree': 0.881310267706623, 'reg_alpha': 2.099256505797962, 'reg_lambda': 3.310977705575762}. Best is trial 1 with value: 0.638943083297139.
# [I 2025-04-15 20:34:35,009] Trial 5 finished with value: 0.6391139931177346 and parameters: {'learning_rate': 0.1724681877768983, 'max_depth': 8, 'num_leaves': 51, 'min_child_samples': 63, 'subsample': 0.9152136760300644, 'colsample_bytree': 0.5888480892074934, 'reg_alpha': 2.6599580876956286, 'reg_lambda': 4.53679930166095}. Best is trial 5 with value: 0.6391139931177346.
# [I 2025-04-15 20:34:57,602] Trial 6 finished with value: 0.6375846275787633 and parameters: {'learning_rate': 0.17492198746047347, 'max_depth': 10, 'num_leaves': 53, 'min_child_samples': 57, 'subsample': 0.6875024240600434, 'colsample_bytree': 0.7688469377967253, 'reg_alpha': 3.868151130074798, 'reg_lambda': 1.2836289529657285}. Best is trial 5 with value: 0.6391139931177346.
# [I 2025-04-15 20:35:24,473] Trial 7 finished with value: 0.6357583849737396 and parameters: {'learning_rate': 0.014119222413295772, 'max_depth': 11, 'num_leaves': 58, 'min_child_samples': 35, 'subsample': 0.6533162664589542, 'colsample_bytree': 0.5663595276117088, 'reg_alpha': 4.2278758564650705, 'reg_lambda': 3.16439196648363}. Best is trial 5 with value: 0.6391139931177346.
# [I 2025-04-15 20:35:34,768] Trial 8 finished with value: 0.6331404749136326 and parameters: {'learning_rate': 0.03817354611664345, 'max_depth': 5, 'num_leaves': 48, 'min_child_samples': 85, 'subsample': 0.5834548674598545, 'colsample_bytree': 0.6608413759565372, 'reg_alpha': 4.470871932837491, 'reg_lambda': 1.224513129712257}. Best is trial 5 with value: 0.6391139931177346.
# [I 2025-04-15 20:35:42,791] Trial 9 finished with value: 0.6347508092795608 and parameters: {'learning_rate': 0.1902296961965997, 'max_depth': 4, 'num_leaves': 46, 'min_child_samples': 21, 'subsample': 0.6422863268159857, 'colsample_bytree': 0.7989236782810958, 'reg_alpha': 2.804941345912748, 'reg_lambda': 2.8510109884763297}. Best is trial 5 with value: 0.6391139931177346.
# [I 2025-04-15 20:35:55,318] Trial 10 finished with value: 0.6369189196805586 and parameters: {'learning_rate': 0.1294014484142501, 'max_depth': 8, 'num_leaves': 15, 'min_child_samples': 68, 'subsample': 0.8219985559062631, 'colsample_bytree': 0.5341853185033152, 'reg_alpha': 0.6341429461175312, 'reg_lambda': 4.865470500652033}. Best is trial 5 with value: 0.6391139931177346.
# [I 2025-04-15 20:36:19,016] Trial 11 finished with value: 0.6397977331609646 and parameters: {'learning_rate': 0.09976884730928703, 'max_depth': 9, 'num_leaves': 61, 'min_child_samples': 65, 'subsample': 0.5310861560486855, 'colsample_bytree': 0.6674800901563939, 'reg_alpha': 3.316971587366708, 'reg_lambda': 4.486970088167747}. Best is trial 11 with value: 0.6397977331609646.
# [I 2025-04-15 20:36:36,296] Trial 12 finished with value: 0.6385742265666163 and parameters: {'learning_rate': 0.09392364445458623, 'max_depth': 7, 'num_leaves': 62, 'min_child_samples': 71, 'subsample': 0.5054760668269236, 'colsample_bytree': 0.6623762102604489, 'reg_alpha': 3.503981486922681, 'reg_lambda': 4.991094761347417}. Best is trial 11 with value: 0.6397977331609646.
# [I 2025-04-15 20:37:01,084] Trial 13 finished with value: 0.6391050080018681 and parameters: {'learning_rate': 0.09529817023859394, 'max_depth': 9, 'num_leaves': 55, 'min_child_samples': 72, 'subsample': 0.8164934058179074, 'colsample_bytree': 0.6006006234705231, 'reg_alpha': 3.300388997567178, 'reg_lambda': 4.187324275814711}. Best is trial 11 with value: 0.6397977331609646.
# [I 2025-04-15 20:37:17,711] Trial 14 finished with value: 0.6385202434369119 and parameters: {'learning_rate': 0.1421309730262147, 'max_depth': 7, 'num_leaves': 61, 'min_child_samples': 56, 'subsample': 0.9722127070749969, 'colsample_bytree': 0.7108431573545857, 'reg_alpha': 4.968976373706917, 'reg_lambda': 4.142364465396193}. Best is trial 11 with value: 0.6397977331609646.
# [I 2025-04-15 20:37:47,608] Trial 15 finished with value: 0.6395998040561671 and parameters: {'learning_rate': 0.08346469714796498, 'max_depth': 9, 'num_leaves': 49, 'min_child_samples': 46, 'subsample': 0.7242471653895846, 'colsample_bytree': 0.5065440731761147, 'reg_alpha': 0.7254361347471376, 'reg_lambda': 4.078776764497354}. Best is trial 11 with value: 0.6397977331609646.
# [I 2025-04-15 20:38:12,192] Trial 16 finished with value: 0.6394108855609446 and parameters: {'learning_rate': 0.07270124746509336, 'max_depth': 10, 'num_leaves': 43, 'min_child_samples': 43, 'subsample': 0.7383809366338591, 'colsample_bytree': 0.5007430925804395, 'reg_alpha': 0.2036941077715313, 'reg_lambda': 2.043909453635761}. Best is trial 11 with value: 0.6397977331609646.
# [I 2025-04-15 20:38:27,173] Trial 17 finished with value: 0.6376206279322114 and parameters: {'learning_rate': 0.11312199405083287, 'max_depth': 6, 'num_leaves': 63, 'min_child_samples': 45, 'subsample': 0.5012132179779181, 'colsample_bytree': 0.7179638625089311, 'reg_alpha': 0.9612628476713061, 'reg_lambda': 3.725920418395929}. Best is trial 11 with value: 0.6397977331609646.
# [I 2025-04-15 20:38:50,090] Trial 18 finished with value: 0.6388980913532317 and parameters: {'learning_rate': 0.07701633174205685, 'max_depth': 9, 'num_leaves': 56, 'min_child_samples': 79, 'subsample': 0.754676658183325, 'colsample_bytree': 0.8024389558415238, 'reg_alpha': 1.593147630217592, 'reg_lambda': 2.18398381602298}. Best is trial 11 with value: 0.6397977331609646.
# [I 2025-04-15 20:39:15,041] Trial 19 finished with value: 0.6400316266042887 and parameters: {'learning_rate': 0.12190979232573267, 'max_depth': 9, 'num_leaves': 50, 'min_child_samples': 31, 'subsample': 0.5676806605846221, 'colsample_bytree': 0.5060200075296913, 'reg_alpha': 0.1741735344507589, 'reg_lambda': 3.9694688181577864}. Best is trial 19 with value: 0.6400316266042887.
# [I 2025-04-15 20:39:22,251] Trial 20 finished with value: 0.6331404660110678 and parameters: {'learning_rate': 0.12301288109072539, 'max_depth': 3, 'num_leaves': 42, 'min_child_samples': 33, 'subsample': 0.5623198108872806, 'colsample_bytree': 0.6231337975919221, 'reg_alpha': 3.2392932183314023, 'reg_lambda': 3.7295194690724616}. Best is trial 19 with value: 0.6400316266042887.
# [I 2025-04-15 20:39:48,539] Trial 21 finished with value: 0.6396537730227003 and parameters: {'learning_rate': 0.08882973929066602, 'max_depth': 9, 'num_leaves': 49, 'min_child_samples': 33, 'subsample': 0.5409545390950623, 'colsample_bytree': 0.5102038628629263, 'reg_alpha': 0.47157272060868793, 'reg_lambda': 4.350907386228036}. Best is trial 19 with value: 0.6400316266042887.
# [I 2025-04-15 20:40:16,948] Trial 22 finished with value: 0.6414980255163371 and parameters: {'learning_rate': 0.14239704564877773, 'max_depth': 10, 'num_leaves': 58, 'min_child_samples': 32, 'subsample': 0.5568923376869163, 'colsample_bytree': 0.5400509724372995, 'reg_alpha': 0.07972396726191594, 'reg_lambda': 4.436427071263507}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:40:44,187] Trial 23 finished with value: 0.6412461339195991 and parameters: {'learning_rate': 0.14781415295704156, 'max_depth': 10, 'num_leaves': 58, 'min_child_samples': 13, 'subsample': 0.5944723420486094, 'colsample_bytree': 0.5531110942943352, 'reg_alpha': 0.2854175971844972, 'reg_lambda': 3.7410958162469674}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:41:11,734] Trial 24 finished with value: 0.640922263872377 and parameters: {'learning_rate': 0.15035713820130753, 'max_depth': 11, 'num_leaves': 58, 'min_child_samples': 12, 'subsample': 0.6037153223366719, 'colsample_bytree': 0.5622380696703385, 'reg_alpha': 0.010500515647614755, 'reg_lambda': 3.6979040968055417}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:41:39,701] Trial 25 finished with value: 0.6401125893613153 and parameters: {'learning_rate': 0.15101952949956252, 'max_depth': 11, 'num_leaves': 57, 'min_child_samples': 12, 'subsample': 0.6095149375953122, 'colsample_bytree': 0.5689338390397695, 'reg_alpha': 1.098455623176462, 'reg_lambda': 3.6235733940591484}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:42:07,795] Trial 26 finished with value: 0.6408143044922229 and parameters: {'learning_rate': 0.16838068961383296, 'max_depth': 10, 'num_leaves': 59, 'min_child_samples': 10, 'subsample': 0.6017935951405411, 'colsample_bytree': 0.5561793096050855, 'reg_alpha': 1.2126645648696277, 'reg_lambda': 2.5009103421983783}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:42:35,190] Trial 27 finished with value: 0.6405084277424702 and parameters: {'learning_rate': 0.14023374232670413, 'max_depth': 12, 'num_leaves': 55, 'min_child_samples': 21, 'subsample': 0.6815459038008124, 'colsample_bytree': 0.6037081332893905, 'reg_alpha': 0.3316356108461309, 'reg_lambda': 4.755617440194275}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:42:55,992] Trial 28 finished with value: 0.6393119246505042 and parameters: {'learning_rate': 0.15861063494260333, 'max_depth': 11, 'num_leaves': 46, 'min_child_samples': 26, 'subsample': 0.6140816484150673, 'colsample_bytree': 0.715191159372505, 'reg_alpha': 0.10142494224958623, 'reg_lambda': 2.9092852265065643}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:43:10,858] Trial 29 finished with value: 0.6378095452134478 and parameters: {'learning_rate': 0.14042077479281664, 'max_depth': 10, 'num_leaves': 29, 'min_child_samples': 17, 'subsample': 0.6987141767771026, 'colsample_bytree': 0.9983328407666283, 'reg_alpha': 0.7932622668428804, 'reg_lambda': 3.619950095423561}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:43:38,911] Trial 30 finished with value: 0.6394019057056844 and parameters: {'learning_rate': 0.18314259544056982, 'max_depth': 11, 'num_leaves': 53, 'min_child_samples': 39, 'subsample': 0.5342978190014416, 'colsample_bytree': 0.5380749655422722, 'reg_alpha': 1.9518266776659563, 'reg_lambda': 4.509369872634003}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:44:06,785] Trial 31 finished with value: 0.6405983950391412 and parameters: {'learning_rate': 0.16202255555932338, 'max_depth': 10, 'num_leaves': 58, 'min_child_samples': 10, 'subsample': 0.6021807319194461, 'colsample_bytree': 0.5576035121924324, 'reg_alpha': 1.2950130123179109, 'reg_lambda': 2.396633810946348}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:44:36,530] Trial 32 finished with value: 0.6414170570940418 and parameters: {'learning_rate': 0.1689328553567814, 'max_depth': 10, 'num_leaves': 59, 'min_child_samples': 17, 'subsample': 0.6314601106676168, 'colsample_bytree': 0.5469882729967388, 'reg_alpha': 0.016713688011781837, 'reg_lambda': 1.8360512861364617}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:45:03,327] Trial 33 finished with value: 0.6414620542985557 and parameters: {'learning_rate': 0.15244727982334869, 'max_depth': 12, 'num_leaves': 53, 'min_child_samples': 17, 'subsample': 0.6409271811329958, 'colsample_bytree': 0.6433236492311531, 'reg_alpha': 0.0710079916049226, 'reg_lambda': 1.6201855784302979}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:45:30,617] Trial 34 finished with value: 0.6412461501060805 and parameters: {'learning_rate': 0.18177369046534497, 'max_depth': 12, 'num_leaves': 52, 'min_child_samples': 27, 'subsample': 0.6451943194080306, 'colsample_bytree': 0.6331683951700504, 'reg_alpha': 0.4793413257656123, 'reg_lambda': 1.6554307419965653}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:45:51,865] Trial 35 finished with value: 0.6404814464965001 and parameters: {'learning_rate': 0.18422564487568033, 'max_depth': 12, 'num_leaves': 36, 'min_child_samples': 18, 'subsample': 0.7794827909203461, 'colsample_bytree': 0.6304166628904991, 'reg_alpha': 0.5250376756404023, 'reg_lambda': 1.6030062752924468}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:46:16,500] Trial 36 finished with value: 0.6410122449275573 and parameters: {'learning_rate': 0.17611944056887596, 'max_depth': 12, 'num_leaves': 53, 'min_child_samples': 28, 'subsample': 0.6452613365210477, 'colsample_bytree': 0.6765814297696102, 'reg_alpha': 0.7963879779309995, 'reg_lambda': 0.04980117668455453}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:46:42,892] Trial 37 finished with value: 0.6395638385036543 and parameters: {'learning_rate': 0.1986830898154013, 'max_depth': 12, 'num_leaves': 52, 'min_child_samples': 24, 'subsample': 0.6677153615389247, 'colsample_bytree': 0.5989100253477273, 'reg_alpha': 2.255090510349517, 'reg_lambda': 0.8625889831994388}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:47:03,761] Trial 38 finished with value: 0.6383853109040281 and parameters: {'learning_rate': 0.1646829295865884, 'max_depth': 12, 'num_leaves': 45, 'min_child_samples': 37, 'subsample': 0.6314987202863581, 'colsample_bytree': 0.9533110869569155, 'reg_alpha': 0.4925339677183703, 'reg_lambda': 1.7521642071287775}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:47:17,958] Trial 39 finished with value: 0.6395458407549025 and parameters: {'learning_rate': 0.13095556195037383, 'max_depth': 11, 'num_leaves': 26, 'min_child_samples': 49, 'subsample': 0.6929455849811801, 'colsample_bytree': 0.6929357151847513, 'reg_alpha': 0.0008149756443734391, 'reg_lambda': 1.078614989174062}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:47:38,422] Trial 40 finished with value: 0.6380884423358782 and parameters: {'learning_rate': 0.18814428778812164, 'max_depth': 8, 'num_leaves': 39, 'min_child_samples': 98, 'subsample': 0.5554237526608332, 'colsample_bytree': 0.640915551102938, 'reg_alpha': 0.9908928390292238, 'reg_lambda': 1.62455715192514}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:48:10,723] Trial 41 finished with value: 0.6410392132243424 and parameters: {'learning_rate': 0.15273113010265663, 'max_depth': 10, 'num_leaves': 63, 'min_child_samples': 17, 'subsample': 0.5813589080037592, 'colsample_bytree': 0.5382226598551562, 'reg_alpha': 0.4258549903738954, 'reg_lambda': 1.8368899949540967}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:48:40,136] Trial 42 finished with value: 0.6408593110039634 and parameters: {'learning_rate': 0.17494251168707808, 'max_depth': 11, 'num_leaves': 60, 'min_child_samples': 21, 'subsample': 0.6260946958327243, 'colsample_bytree': 0.5866624617006684, 'reg_alpha': 0.34568031194586457, 'reg_lambda': 1.4596665913354154}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:49:06,231] Trial 43 finished with value: 0.6404274722693604 and parameters: {'learning_rate': 0.11239411671193407, 'max_depth': 12, 'num_leaves': 56, 'min_child_samples': 28, 'subsample': 0.6521744139557906, 'colsample_bytree': 0.7566429036859472, 'reg_alpha': 1.4498173750372212, 'reg_lambda': 0.5278215195083684}. Best is trial 22 with value: 0.6414980255163371.
# [I 2025-04-15 20:49:35,769] Trial 44 finished with value: 0.641695939648639 and parameters: {'learning_rate': 0.14372838878531902, 'max_depth': 11, 'num_leaves': 54, 'min_child_samples': 15, 'subsample': 0.577664261766455, 'colsample_bytree': 0.531318646283099, 'reg_alpha': 0.279192517570013, 'reg_lambda': 1.9479684324963837}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:50:03,467] Trial 45 finished with value: 0.6413810850669365 and parameters: {'learning_rate': 0.1333100210891424, 'max_depth': 12, 'num_leaves': 54, 'min_child_samples': 21, 'subsample': 0.6650222196767409, 'colsample_bytree': 0.6197382181841679, 'reg_alpha': 0.6390312246015513, 'reg_lambda': 2.0683429332841423}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:50:30,970] Trial 46 finished with value: 0.6408502910871616 and parameters: {'learning_rate': 0.13140757523827387, 'max_depth': 11, 'num_leaves': 54, 'min_child_samples': 21, 'subsample': 0.709328730307616, 'colsample_bytree': 0.5801505475882808, 'reg_alpha': 0.7910432469783588, 'reg_lambda': 1.9768736364000143}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:50:58,464] Trial 47 finished with value: 0.6405084394776693 and parameters: {'learning_rate': 0.1382167789051538, 'max_depth': 12, 'num_leaves': 48, 'min_child_samples': 16, 'subsample': 0.5486618369358585, 'colsample_bytree': 0.5267841060394665, 'reg_alpha': 0.19388917369281178, 'reg_lambda': 2.585472405845244}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:51:10,348] Trial 48 finished with value: 0.6370358568926627 and parameters: {'learning_rate': 0.12223006532123785, 'max_depth': 10, 'num_leaves': 15, 'min_child_samples': 23, 'subsample': 0.8918558371912003, 'colsample_bytree': 0.6142798280031275, 'reg_alpha': 0.6553132867155418, 'reg_lambda': 2.2003749077728534}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:51:39,532] Trial 49 finished with value: 0.6406973656614705 and parameters: {'learning_rate': 0.1577050669082948, 'max_depth': 11, 'num_leaves': 60, 'min_child_samples': 40, 'subsample': 0.667788025876207, 'colsample_bytree': 0.645361877086025, 'reg_alpha': 0.045925412746471904, 'reg_lambda': 3.08081110842532}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:52:06,066] Trial 50 finished with value: 0.6403644943119003 and parameters: {'learning_rate': 0.14636148234032767, 'max_depth': 11, 'num_leaves': 50, 'min_child_samples': 18, 'subsample': 0.5159720011340564, 'colsample_bytree': 0.5812819145227938, 'reg_alpha': 1.7741088539838954, 'reg_lambda': 1.3358066941891105}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:52:29,564] Trial 51 finished with value: 0.6401036171946337 and parameters: {'learning_rate': 0.17133076983847126, 'max_depth': 12, 'num_leaves': 51, 'min_child_samples': 29, 'subsample': 0.5779447007126762, 'colsample_bytree': 0.6514191220824948, 'reg_alpha': 0.5485855474901763, 'reg_lambda': 1.0151254698250387}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:52:59,274] Trial 52 finished with value: 0.6393659191107458 and parameters: {'learning_rate': 0.17992549297963523, 'max_depth': 12, 'num_leaves': 55, 'min_child_samples': 26, 'subsample': 0.6334744351761897, 'colsample_bytree': 0.5225011420560177, 'reg_alpha': 0.9307414902240916, 'reg_lambda': 2.2755103439741236}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:53:23,095] Trial 53 finished with value: 0.6395548287034034 and parameters: {'learning_rate': 0.19211614767101554, 'max_depth': 12, 'num_leaves': 52, 'min_child_samples': 52, 'subsample': 0.6639919655648365, 'colsample_bytree': 0.6847547219685506, 'reg_alpha': 0.3097856651992461, 'reg_lambda': 1.8997300408586317}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:53:37,143] Trial 54 finished with value: 0.638889104214055 and parameters: {'learning_rate': 0.1331280934052786, 'max_depth': 11, 'num_leaves': 20, 'min_child_samples': 14, 'subsample': 0.7198579739161394, 'colsample_bytree': 0.6189999367124629, 'reg_alpha': 0.6770505013332855, 'reg_lambda': 2.664467622422193}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:54:08,223] Trial 55 finished with value: 0.635956303557324 and parameters: {'learning_rate': 0.011881205907114459, 'max_depth': 12, 'num_leaves': 61, 'min_child_samples': 32, 'subsample': 0.6245291087179334, 'colsample_bytree': 0.8278998293808904, 'reg_alpha': 0.17564789731887112, 'reg_lambda': 1.4571957721573114}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:54:29,501] Trial 56 finished with value: 0.6394288825003724 and parameters: {'learning_rate': 0.10674244890401705, 'max_depth': 7, 'num_leaves': 56, 'min_child_samples': 19, 'subsample': 0.7568636964389851, 'colsample_bytree': 0.7291543385844476, 'reg_alpha': 0.3606451952417812, 'reg_lambda': 1.6836398929142136}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:54:53,302] Trial 57 finished with value: 0.640337500116745 and parameters: {'learning_rate': 0.1658174015191954, 'max_depth': 11, 'num_leaves': 43, 'min_child_samples': 24, 'subsample': 0.5835932376796342, 'colsample_bytree': 0.6053969543826769, 'reg_alpha': 1.1943540067698077, 'reg_lambda': 2.0343989862153764}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:55:16,955] Trial 58 finished with value: 0.6385742366831673 and parameters: {'learning_rate': 0.15888796290505502, 'max_depth': 9, 'num_leaves': 47, 'min_child_samples': 14, 'subsample': 0.684025557953563, 'colsample_bytree': 0.5766588269432065, 'reg_alpha': 2.965800874777983, 'reg_lambda': 2.3552370005806527}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:55:36,254] Trial 59 finished with value: 0.637737558669723 and parameters: {'learning_rate': 0.054383379610050096, 'max_depth': 6, 'num_leaves': 54, 'min_child_samples': 35, 'subsample': 0.5157144325774864, 'colsample_bytree': 0.5460153370425987, 'reg_alpha': 0.926479066495024, 'reg_lambda': 0.8923772567590325}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:56:02,814] Trial 60 finished with value: 0.6386641792954539 and parameters: {'learning_rate': 0.14433268686555728, 'max_depth': 10, 'num_leaves': 59, 'min_child_samples': 60, 'subsample': 0.560738262207177, 'colsample_bytree': 0.5182560778229759, 'reg_alpha': 3.983486702130902, 'reg_lambda': 2.1272688520187804}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:56:33,696] Trial 61 finished with value: 0.6413450879507847 and parameters: {'learning_rate': 0.14874469979680305, 'max_depth': 10, 'num_leaves': 57, 'min_child_samples': 12, 'subsample': 0.5915896414766588, 'colsample_bytree': 0.5498996870107631, 'reg_alpha': 0.21780961837516372, 'reg_lambda': 1.5133917599054616}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:57:04,551] Trial 62 finished with value: 0.6403465026330792 and parameters: {'learning_rate': 0.15550903990185766, 'max_depth': 11, 'num_leaves': 56, 'min_child_samples': 10, 'subsample': 0.5914759289538096, 'colsample_bytree': 0.5408080555344585, 'reg_alpha': 0.2514840912456245, 'reg_lambda': 1.205471761012872}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:57:34,712] Trial 63 finished with value: 0.6414890408051324 and parameters: {'learning_rate': 0.12568121971377041, 'max_depth': 10, 'num_leaves': 61, 'min_child_samples': 15, 'subsample': 0.6175227756560496, 'colsample_bytree': 0.5681498116323453, 'reg_alpha': 0.6142688455846195, 'reg_lambda': 1.3927983038665754}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:58:04,634] Trial 64 finished with value: 0.6415970005899487 and parameters: {'learning_rate': 0.12016694487406483, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 14, 'subsample': 0.5689493178061081, 'colsample_bytree': 0.5664133624999607, 'reg_alpha': 0.1912296304832804, 'reg_lambda': 1.4931133940169539}. Best is trial 44 with value: 0.641695939648639.
# [I 2025-04-15 20:58:32,304] Trial 65 finished with value: 0.6417589204387333 and parameters: {'learning_rate': 0.10149684167289144, 'max_depth': 8, 'num_leaves': 62, 'min_child_samples': 16, 'subsample': 0.5267993258972139, 'colsample_bytree': 0.5646882380681456, 'reg_alpha': 0.015334301554397634, 'reg_lambda': 1.2773777699697177}. Best is trial 65 with value: 0.6417589204387333.
# [I 2025-04-15 20:59:01,266] Trial 66 finished with value: 0.6405893957601033 and parameters: {'learning_rate': 0.11786240216059041, 'max_depth': 8, 'num_leaves': 63, 'min_child_samples': 15, 'subsample': 0.5238241377950084, 'colsample_bytree': 0.5007132251467403, 'reg_alpha': 0.031163898197619923, 'reg_lambda': 1.294998556047922}. Best is trial 65 with value: 0.6417589204387333.
# [I 2025-04-15 20:59:29,939] Trial 67 finished with value: 0.6414980259209991 and parameters: {'learning_rate': 0.10280336849806765, 'max_depth': 9, 'num_leaves': 61, 'min_child_samples': 19, 'subsample': 0.5405910820508041, 'colsample_bytree': 0.5708289987078022, 'reg_alpha': 0.0028386095970731173, 'reg_lambda': 1.1403613924754898}. Best is trial 65 with value: 0.6417589204387333.
# [I 2025-04-15 20:59:58,756] Trial 68 finished with value: 0.6418848799956115 and parameters: {'learning_rate': 0.10431463346174925, 'max_depth': 9, 'num_leaves': 61, 'min_child_samples': 23, 'subsample': 0.5428139485094721, 'colsample_bytree': 0.5655722177254241, 'reg_alpha': 0.15725447018730654, 'reg_lambda': 0.7066374887881189}. Best is trial 68 with value: 0.6418848799956115.
# [I 2025-04-15 21:00:28,522] Trial 69 finished with value: 0.6414980323955917 and parameters: {'learning_rate': 0.10046884004815232, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 20, 'subsample': 0.5433494687790688, 'colsample_bytree': 0.5660865735576768, 'reg_alpha': 0.4473324528745917, 'reg_lambda': 0.7011984266532174}. Best is trial 68 with value: 0.6418848799956115.
# [I 2025-04-15 21:00:58,239] Trial 70 finished with value: 0.6424246429047715 and parameters: {'learning_rate': 0.10060123023174604, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 23, 'subsample': 0.5006824942780478, 'colsample_bytree': 0.5935244944749666, 'reg_alpha': 0.4053472537289082, 'reg_lambda': 0.27630401721982417}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:01:27,787] Trial 71 finished with value: 0.6414440541218316 and parameters: {'learning_rate': 0.1002766350178801, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 24, 'subsample': 0.5005414695662169, 'colsample_bytree': 0.5919640955834535, 'reg_alpha': 0.39530629616668217, 'reg_lambda': 0.31011026426384686}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:01:55,652] Trial 72 finished with value: 0.6411561690509003 and parameters: {'learning_rate': 0.09168123225686833, 'max_depth': 8, 'num_leaves': 63, 'min_child_samples': 30, 'subsample': 0.5377251034516022, 'colsample_bytree': 0.5680273657084716, 'reg_alpha': 0.16612293904188485, 'reg_lambda': 0.7009423711633116}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:02:26,216] Trial 73 finished with value: 0.6411651642833179 and parameters: {'learning_rate': 0.07245202033030988, 'max_depth': 9, 'num_leaves': 60, 'min_child_samples': 20, 'subsample': 0.5433613831465761, 'colsample_bytree': 0.5268828714348166, 'reg_alpha': 0.300385116734961, 'reg_lambda': 0.2965658265084593}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:02:52,714] Trial 74 finished with value: 0.6395638271731173 and parameters: {'learning_rate': 0.10085460394019262, 'max_depth': 8, 'num_leaves': 62, 'min_child_samples': 91, 'subsample': 0.5220239363272847, 'colsample_bytree': 0.5163303328054984, 'reg_alpha': 0.4725053616725635, 'reg_lambda': 0.6921400749026205}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:03:20,949] Trial 75 finished with value: 0.6419658330407492 and parameters: {'learning_rate': 0.08241075592122113, 'max_depth': 9, 'num_leaves': 59, 'min_child_samples': 23, 'subsample': 0.5676936215451736, 'colsample_bytree': 0.5598928192570082, 'reg_alpha': 0.1933034610855074, 'reg_lambda': 0.46763009649700316}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:03:45,826] Trial 76 finished with value: 0.6395907987071986 and parameters: {'learning_rate': 0.08398156485051418, 'max_depth': 9, 'num_leaves': 61, 'min_child_samples': 23, 'subsample': 0.5701981729888933, 'colsample_bytree': 0.8881218053455495, 'reg_alpha': 4.746032445853668, 'reg_lambda': 0.08967847081067415}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:04:10,022] Trial 77 finished with value: 0.6407603428096065 and parameters: {'learning_rate': 0.1110545853858374, 'max_depth': 7, 'num_leaves': 59, 'min_child_samples': 12, 'subsample': 0.5322768990536595, 'colsample_bytree': 0.5596884099262851, 'reg_alpha': 0.8270693812315048, 'reg_lambda': 0.3844912895278527}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:04:38,396] Trial 78 finished with value: 0.6399596691962307 and parameters: {'learning_rate': 0.0839144425934502, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 26, 'subsample': 0.5100420088849026, 'colsample_bytree': 0.5996499387927495, 'reg_alpha': 2.3572989071153487, 'reg_lambda': 0.5284392465369185}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:05:04,544] Trial 79 finished with value: 0.6411741716555965 and parameters: {'learning_rate': 0.09660566651806282, 'max_depth': 8, 'num_leaves': 57, 'min_child_samples': 19, 'subsample': 0.5522160023998085, 'colsample_bytree': 0.5800106176314905, 'reg_alpha': 0.20241584560870196, 'reg_lambda': 0.8369993341956172}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:05:33,554] Trial 80 finished with value: 0.6412911129143211 and parameters: {'learning_rate': 0.10409028676466248, 'max_depth': 8, 'num_leaves': 60, 'min_child_samples': 10, 'subsample': 0.568990063739927, 'colsample_bytree': 0.5317983486980487, 'reg_alpha': 0.5548984421957437, 'reg_lambda': 0.18816486905295882}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:06:02,580] Trial 81 finished with value: 0.6412821035187324 and parameters: {'learning_rate': 0.1163446261313994, 'max_depth': 9, 'num_leaves': 58, 'min_child_samples': 21, 'subsample': 0.530158644037453, 'colsample_bytree': 0.5448008400309912, 'reg_alpha': 0.1312208505608557, 'reg_lambda': 1.1331324399121603}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:06:32,086] Trial 82 finished with value: 0.6413810664524828 and parameters: {'learning_rate': 0.0681081935192604, 'max_depth': 9, 'num_leaves': 63, 'min_child_samples': 35, 'subsample': 0.5506891351279455, 'colsample_bytree': 0.5601387278656844, 'reg_alpha': 0.389907465859786, 'reg_lambda': 0.6557836746170499}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:06:59,923] Trial 83 finished with value: 0.6414800277675853 and parameters: {'learning_rate': 0.09165551403562402, 'max_depth': 9, 'num_leaves': 58, 'min_child_samples': 23, 'subsample': 0.5646099436196127, 'colsample_bytree': 0.5913917265043769, 'reg_alpha': 0.012773563169514557, 'reg_lambda': 1.030445019547723}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:07:26,551] Trial 84 finished with value: 0.6410842043589255 and parameters: {'learning_rate': 0.0786833498100421, 'max_depth': 8, 'num_leaves': 60, 'min_child_samples': 30, 'subsample': 0.5082472897422624, 'colsample_bytree': 0.5719487813030718, 'reg_alpha': 0.2825207267532104, 'reg_lambda': 0.807521710928333}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:07:57,574] Trial 85 finished with value: 0.6415969848081293 and parameters: {'learning_rate': 0.10862916064305256, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 26, 'subsample': 0.5410899906085215, 'colsample_bytree': 0.5314876105808034, 'reg_alpha': 0.12645670938750592, 'reg_lambda': 0.3993426345078754}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:08:27,523] Trial 86 finished with value: 0.6407693230695286 and parameters: {'learning_rate': 0.10627406763644773, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 76, 'subsample': 0.5399749221397071, 'colsample_bytree': 0.5112514102199105, 'reg_alpha': 0.5218008119225684, 'reg_lambda': 0.5989345180549865}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:08:54,440] Trial 87 finished with value: 0.6413900580429421 and parameters: {'learning_rate': 0.0887676610932365, 'max_depth': 8, 'num_leaves': 61, 'min_child_samples': 26, 'subsample': 0.5226602799687577, 'colsample_bytree': 0.6093932439738293, 'reg_alpha': 0.7083524795658954, 'reg_lambda': 0.43113797390534764}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:09:19,638] Trial 88 finished with value: 0.6406163911692448 and parameters: {'learning_rate': 0.11632663750800963, 'max_depth': 7, 'num_leaves': 63, 'min_child_samples': 17, 'subsample': 0.5004232587456707, 'colsample_bytree': 0.5537693152266246, 'reg_alpha': 0.13489705093569712, 'reg_lambda': 0.2007160275169111}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:09:51,538] Trial 89 finished with value: 0.6386282052450383 and parameters: {'learning_rate': 0.02347388637212812, 'max_depth': 9, 'num_leaves': 59, 'min_child_samples': 13, 'subsample': 0.5751813574129587, 'colsample_bytree': 0.5299487215069187, 'reg_alpha': 0.41535298814082244, 'reg_lambda': 0.9514210035642213}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:10:20,375] Trial 90 finished with value: 0.6410122230758073 and parameters: {'learning_rate': 0.09594419297748988, 'max_depth': 9, 'num_leaves': 61, 'min_child_samples': 19, 'subsample': 0.5450297126561223, 'colsample_bytree': 0.5922610584834702, 'reg_alpha': 0.28420879912827335, 'reg_lambda': 1.1859163862311397}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:10:51,329] Trial 91 finished with value: 0.6414440407679844 and parameters: {'learning_rate': 0.10233918488070101, 'max_depth': 10, 'num_leaves': 57, 'min_child_samples': 22, 'subsample': 0.5572996721922813, 'colsample_bytree': 0.5406441167730109, 'reg_alpha': 0.12698728410228516, 'reg_lambda': 0.46216773619995144}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:11:21,256] Trial 92 finished with value: 0.6411111815582755 and parameters: {'learning_rate': 0.10968770373363279, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 26, 'subsample': 0.5346951760803901, 'colsample_bytree': 0.5643702430116841, 'reg_alpha': 0.11832623201747615, 'reg_lambda': 0.7423014556885998}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:11:52,093] Trial 93 finished with value: 0.6407063629171983 and parameters: {'learning_rate': 0.12681299251762793, 'max_depth': 9, 'num_leaves': 59, 'min_child_samples': 15, 'subsample': 0.5867393395417979, 'colsample_bytree': 0.5173813496179104, 'reg_alpha': 0.41552769521781263, 'reg_lambda': 0.2666184959725644}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:12:11,896] Trial 94 finished with value: 0.6389430747992362 and parameters: {'learning_rate': 0.09740139528250238, 'max_depth': 10, 'num_leaves': 33, 'min_child_samples': 28, 'subsample': 0.6042477325870539, 'colsample_bytree': 0.5744019531976935, 'reg_alpha': 0.025599089957322768, 'reg_lambda': 0.5572816909819752}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:12:38,761] Trial 95 finished with value: 0.6412281256496344 and parameters: {'learning_rate': 0.11868686799941486, 'max_depth': 8, 'num_leaves': 60, 'min_child_samples': 33, 'subsample': 0.9942786893927933, 'colsample_bytree': 0.5537169541617118, 'reg_alpha': 0.5996990741800682, 'reg_lambda': 0.9774687120074587}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:13:04,558] Trial 96 finished with value: 0.6404904514408065 and parameters: {'learning_rate': 0.08794159357451589, 'max_depth': 10, 'num_leaves': 58, 'min_child_samples': 25, 'subsample': 0.5171357887834072, 'colsample_bytree': 0.7865817851297816, 'reg_alpha': 0.25834975740549593, 'reg_lambda': 0.10760212645240763}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:13:31,923] Trial 97 finished with value: 0.6391320135275605 and parameters: {'learning_rate': 0.13653608944438395, 'max_depth': 9, 'num_leaves': 63, 'min_child_samples': 19, 'subsample': 0.5592982780597283, 'colsample_bytree': 0.5326336841407878, 'reg_alpha': 3.5681060492765777, 'reg_lambda': 3.3926290019421823}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:14:01,285] Trial 98 finished with value: 0.6418128942612109 and parameters: {'learning_rate': 0.07977129687688651, 'max_depth': 10, 'num_leaves': 57, 'min_child_samples': 16, 'subsample': 0.5262051487625256, 'colsample_bytree': 0.5846157205906428, 'reg_alpha': 0.7400389316821154, 'reg_lambda': 0.021886955543066633}. Best is trial 70 with value: 0.6424246429047715.
# [I 2025-04-15 21:14:29,956] Trial 99 finished with value: 0.6413810717130893 and parameters: {'learning_rate': 0.06372398217714634, 'max_depth': 10, 'num_leaves': 55, 'min_child_samples': 16, 'subsample': 0.5107210779101564, 'colsample_bytree': 0.5895349473561576, 'reg_alpha': 0.8744141019453834, 'reg_lambda': 0.4181127259211909}. Best is trial 70 with value: 0.6424246429047715.
# Best params: {'learning_rate': 0.10060123023174604, 'max_depth': 9, 'num_leaves': 62, 'min_child_samples': 23, 'subsample': 0.5006824942780478, 'colsample_bytree': 0.5935244944749666, 'reg_alpha': 0.4053472537289082, 'reg_lambda': 0.27630401721982417}
#
# Final Balanced Accuracy on held-out validation set: 0.4146

# %%
# Apply the model to the test data
# === Load and preprocess test.csv ===
test_df = pd.read_csv("test.csv")
test_ids = test_df['Id']

# Drop columns not used in prediction
drop_cols_test = ['Found Location', 'Date of Birth', 'Id']
X_test = test_df.drop(columns=drop_cols_test, errors='ignore')

# Feature engineering (same as training)
X_test['Color Category'] = X_test['Color'].apply(simplify_color)
X_test.drop(columns=['Color'], inplace=True)

X_test['Age in Days'] = X_test['Age upon Intake'].apply(age_to_days)
X_test.drop(columns=['Age upon Intake'], inplace=True)

X_test['Intake Time'] = pd.to_datetime(test_df['Intake Time'], errors='coerce')
X_test['Intake Hour'] = X_test['Intake Time'].dt.hour
X_test['Weekday'] = X_test['Intake Time'].dt.weekday
X_test['Season'] = X_test['Intake Time'].dt.month.map({
    12: 'winter', 1: 'winter', 2: 'winter',
    3: 'spring', 4: 'spring', 5: 'spring',
    6: 'summer', 7: 'summer', 8: 'summer',
    9: 'fall', 10: 'fall', 11: 'fall'
})
X_test.drop(columns=['Intake Time'], inplace=True, errors='ignore')

# Fill missing values
for col in X_test.columns:
    if X_test[col].dtype == 'object':
        X_test[col] = X_test[col].fillna("Unknown")
    else:
        X_test[col] = X_test[col].fillna(X_test[col].median())

# Ensure categorical types match training
for col in categorical_cols:
    if col in X_test.columns:
        X_test[col] = X_test[col].astype('category')

X_test.head()
# Out:
# /var/folders/vt/p1bz6vtn791cmw2wdgby6fth0000gn/T/ipykernel_33576/1776531819.py:17: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   X_test['Intake Time'] = pd.to_datetime(test_df['Intake Time'], errors='coerce')
#   Intake Type Intake Condition Animal Type Sex upon Intake  \
# 0       Stray           Normal         Dog   Neutered Male
# 1       Stray             Sick         Cat   Intact Female
# 2       Stray           Normal         Dog   Neutered Male
# 3       Stray           Normal         Dog   Intact Female
# 4       Stray          Injured         Cat   Intact Female
#
#                                    Breed Color Category  Age in Days  \
# 0                             Beagle Mix          other          730
# 1                 Domestic Shorthair Mix          other           28
# 2  Doberman Pinsch/Australian Cattle Dog          mixed         1460
# 3                               Pit Bull          mixed          150
# 4                 Domestic Shorthair Mix          mixed          730
#
#    Intake Hour  Weekday  Season
# 0           16        3  winter
# 1            7        0    fall
# 2           10        6  summer
# 3           18        5  summer
# 4           10        5  winter

# %%
# === Make predictions ===

y_test_pred = final_model.predict(X_test)
y_test_labels = le_y.inverse_transform(y_test_pred)

# === Create submission ===
submission_df = pd.DataFrame({
    'Id': test_ids,
    'Outcome Type': y_test_labels
})

submission_df.to_csv("submission4146.csv", index=False)
print("submission.csv created with test predictions!")
# Out:
# submission.csv created with test predictions!
